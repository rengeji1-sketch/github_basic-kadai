# %% [markdown]
# <a href="https://colab.research.google.com/github/rengeji1-sketch/github_basic-kadai/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
the_top_side = 10
the_bottom_side = 20
height = 5
trapezoid_area = ((the_top_side + the_bottom_side) * height / 2)
print(str(trapezoid_area) + "㎠")
# Out:
# 75.0㎠
